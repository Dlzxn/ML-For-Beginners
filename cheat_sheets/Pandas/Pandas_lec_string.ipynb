# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Строки в DataFrame и работа с ними
# --

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycolumns)
df.info() - выводит информацию о дф
df.index - атрибут, в котором хранится RangeIndex, содержащий индексы в формате: [0; 244)
df.set_index('Payment ID') - установление колонки вместо цифровых индексов и других любых
df.head() - возврат первых пяти элементов
df.tail() - возврат последних пяти элементов
df.reset_index() - сброс индекса
df.describe() - анализ дф по колонкам
df.transpose() - транспонирование дф
df.reset_index() - обнуление индексов, возврат к цифровым индексам, колонка именных индексов становится опять колонкой
df.iloc[] - возврат элемента по цифровому индексу
df.loc[] - возврат элемента по именной индексу
df.loc[[]] - возврат нескольких элементов по именному индексу
df.drop('',axis=0) - удаление элемента
pd.concat([df,pd.DataFrame([one_row])],axis=0) - добавление элемента дф
# Out:
#   Cell In[38], line 3
#     df.index - атрибут, в котором хранится RangeIndex, содержащий индексы в формате: [0; 244)
#                                                                                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.index
# Out:
# Index(['Sun2959', 'Sun4608', 'Sun4458', 'Sun5260', 'Sun2251', 'Sun9679',
#        'Sun5985', 'Sun8157', 'Sun6820', 'Sun3775',
#        ...
#        'Sat7220', 'Sat4615', 'Sat5032', 'Sat2929', 'Sat9777', 'Sat2657',
#        'Sat1766', 'Sat3880', 'Sat17', 'Thur672'],
#       dtype='object', name='Payment ID', length=244)

# %%
df["ind"] = pd.Series([x for x in range(5, 1000)])
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  ind
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410  NaN
# ...

# %%
df = df.set_index("Payment ID")
df.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48416/2501248880.py in ?()
# ----> 1 df = df.set_index("Payment ID")
#       2 df.index
#
# ~/dev/python/ML-Learning/.venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6125                     if not found:
#    6126                         missing.append(col)
#    6127
#    6128         if missing:
# -> 6129             raise KeyError(f"None of {missing} are in the columns")
#    6130
#    6131         if inplace:
#    6132             frame = self
#
# KeyError: "None of ['Payment ID'] are in the columns"

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  ind
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410    5
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  ind
# Payment ID
# ...

# %%
df = df.reset_index()
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index("Payment ID")
df

# %% [markdown]
# **Доступ к строкам по числову индексу**
# --

# %%
df.iloc[0] # нудевая строка
# Out:
# Payment ID                     Sun2959
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# ind                                  5
# Name: 0, dtype: object

# %% [markdown]
# **Доступ к строке по именовоному индексу**
# --

# %%
df.loc["Sun2959"]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# ind                                NaN
# Name: Sun2959, dtype: object

# %%
df.iloc[1: 6]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number  ind
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230  NaN
# Sun4458                 7.00    Travis Walters  6011812112971322  NaN
# Sun5260                11.84  Nathaniel Harris  4676137647685994  NaN
# Sun2251                 6.15      Tonya Carter  4832732618637221  NaN
# Sun9679                 6.32        Erik Smith   213140353657882  NaN

# %%
df.loc[["Sun2959", "Sun9679"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  ind
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410  NaN
# Sun9679                 6.32          Erik Smith   213140353657882  NaN

# %% [markdown]
# **Удаление строк**

# %%
df.drop("Sun2959", axis = 0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number  ind
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230  NaN
# ...

# %% [markdown]
# **Добавление новой строки**
# --

# %%
new_str = df.iloc[0]
pd.concat([df, new_str.to_frame().T])
# Out:
#         total_bill   tip     sex smoker   day    time size price_per_person  \
# Sun2959      16.99  1.01  Female     No   Sun  Dinner    2             8.49
# Sun4608      10.34  1.66    Male     No   Sun  Dinner    3             3.45
# Sun4458      21.01   3.5    Male     No   Sun  Dinner    3              7.0
# Sun5260      23.68  3.31    Male     No   Sun  Dinner    2            11.84
# Sun2251      24.59  3.61  Female     No   Sun  Dinner    4             6.15
# ...            ...   ...     ...    ...   ...     ...  ...              ...
# Sat1766      27.18   2.0  Female    Yes   Sat  Dinner    2            13.59
# Sat3880      22.67   2.0    Male    Yes   Sat  Dinner    2            11.34
# Sat17        17.82  1.75    Male     No   Sat  Dinner    2             8.91
# Thur672      18.78   3.0  Female     No  Thur  Dinner    2             9.39
# Sun2959      16.99  1.01  Female     No   Sun  Dinner    2             8.49
#
#                  Payer Name         CC Number  ind
# ...

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  ind
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410  NaN
# ...
